# %%
import pandas as pd
import numpy as np
import string

# %%
df= pd.read_excel('stats/itm-apr17-tables.xls', sheetname=8)
row_count, col_count = df.shape
col_names = [string.ascii_uppercase[i] for i in range(col_count)]
df.columns = col_names
df.drop(['I','J'],axis='columns', inplace=True)
df.rename(columns={'A':'Region','B':'Country'},inplace=True)
df
# Out:
#                                          Region  \
# 0                                           NaN
# 1      Net permanent and long-term migration(1)
# 2   By country of last/next permanent residence
# 3                                           NaN
# 4                          Country of last/next
# 5                           permanent residence
# 6                                           NaN
# 7                                       Oceania
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                         Asia
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# ...

# %%
df1 = df.iloc[7:52].replace(np.nan,'').dropna(axis='index',how='all').set_index(['Region','Country'])
df1.rename(columns={'C':'Apr-2015','D':'Apr-2016','E':'Apr-2017','F':'2015','G':'2016','H':'2017'})
# Out:
#                                                        Apr-2015 Apr-2016  \
# Region                     Country
# Oceania                                                     261      197
#                            Australia                         63      -78
#                            Fiji                              49      142
#                            Samoa                             65      104
#                            Tonga                             61       32
#
# Asia                                                       2159     2314
#                            China, People's Republic of      446      485
#                            Hong Kong (SAR)                   35       68
#                            India                            667      621
#                            Indonesia                          9       16
#                            Japan                            263      316
# ...

# %%
df1.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-1a84cdfdea9b> in <module>()
# ----> 1 df1.plot()
#
# ~/venvs/jupyter/lib/python3.5/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2615                           fontsize=fontsize, colormap=colormap, table=table,
#    2616                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2617                           sort_columns=sort_columns, **kwds)
#    2618     __call__.__doc__ = plot_frame.__doc__
#    2619
#
# ...
