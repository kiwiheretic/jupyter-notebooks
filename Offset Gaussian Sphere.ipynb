# %%
from sympy import *
x,y,z = symbols('x y z')
a,ax, b,c,r,alpha, k, ka = symbols('a a_x b c r alpha k k_a', real=True, positive=True)
beta, q, eps0 = symbols('beta q epsilon_0', real=True)

# %%
from mylibs.plots import plotfn
import numpy as np
import scipy as sp

# %%
init_printing()

# %%
# %matplotlib inline

# %% [markdown]
# ![charge-in-sphere.png](attachment:charge-in-sphere.png)

# %%
from sympy.vector import CoordSysCartesian
N = CoordSysCartesian('N')

# %% [markdown]
# $\tilde{p}$ is any point on a sphere.  $\alpha$ is the angle made inside and at the origin of the x-y plane from the positive x axis and ranges $ 0 \leq \alpha \leq 2\pi$.  $\beta$ is the angle made between the x-y plane and vertically parallel to the z axis ranging from $-\pi \leq \beta \leq \pi$.

# %%
p = r*(cos(alpha)*cos(beta)*N.i+sin(alpha)*cos(beta)*N.j+sin(beta)*N.k)
p
# Out:
# (r⋅cos(α)⋅cos(β)) N_i + (r⋅sin(α)⋅cos(β)) N_j + (r⋅sin(β)) N_k

# %% [markdown]
# Calculate $\frac{\delta \tilde{p}}{\delta \alpha}$

# %%
pa = diff(p,alpha)
pa
# Out:
# (-r⋅sin(α)⋅cos(β)) N_i + (r⋅cos(α)⋅cos(β)) N_j

# %% [markdown]
# Calculate $\frac{\delta \tilde{p}}{\delta \beta}$

# %%
pb = diff(p,beta)
pb
# Out:
# (-r⋅sin(β)⋅cos(α)) N_i + (-r⋅sin(α)⋅sin(β)) N_j + (r⋅cos(β)) N_k

# %% [markdown]
# Calculate $\frac{\delta \tilde{p}}{\delta \alpha} \times \frac{\delta \tilde{p}}{\delta \beta} $

# %%
px = pa.cross(pb)
px.simplify()
# Out:
# ⎛ 2           2   ⎞ N_i + ⎛ 2           2   ⎞ N_j + ⎛ 2         ⎞ N_k
# ⎝r ⋅cos(α)⋅cos (β)⎠       ⎝r ⋅sin(α)⋅cos (β)⎠       ⎜r ⋅sin(2⋅β)⎟
#                                                     ⎜───────────⎟
#                                                     ⎝     2     ⎠

# %% [markdown]
# Calculate $\left | \frac{\delta \tilde{p}}{\delta \alpha} \times \frac{\delta \tilde{p}}{\delta \beta} \right |$

# %%
norm_cross = sqrt(px.dot(px).simplify())
norm_cross
# Out:
#  2
# r ⋅│cos(β)│

# %% [markdown]
# Compute the normal unit vector at the surface of the sphere

# %%
px2 = px/(r**2*cos(beta))
nuv = px2.args[0]+px2.args[1]+px2.args[2].simplify()
nuv
# Out:
# (cos(α)⋅cos(β)) N_i + (sin(α)⋅cos(β)) N_j + (sin(β)) N_k

# %% [markdown]
# Compute $\tilde{p} - \tilde{a}$ where $\tilde{a}$ = &lt;a<sub>x</sub>, 0, 0&gt;

# %%
p2 = (r*cos(alpha)*cos(beta)-ax)*N.i + r*sin(alpha)*cos(beta)*N.j + r*sin(beta)*N.k
p2
# Out:
# (-aₓ + r⋅cos(α)⋅cos(β)) N_i + (r⋅sin(α)⋅cos(β)) N_j + (r⋅sin(β)) N_k

# %% [markdown]
# Compute the unit vector of $\tilde{p} - \tilde{a}$

# %%
puv = p2/p2.magnitude()
puv
# Out:
# ⎛                     -aₓ + r⋅cos(α)⋅cos(β)                     ⎞ N_i + ⎛
# ⎜───────────────────────────────────────────────────────────────⎟       ⎜─────
# ⎜   ____________________________________________________________⎟       ⎜   __
# ⎜  ╱  2    2       2       2    2                             2 ⎟       ⎜  ╱
# ⎝╲╱  r ⋅sin (α)⋅cos (β) + r ⋅sin (β) + (-aₓ + r⋅cos(α)⋅cos(β))  ⎠       ⎝╲╱  r
#
#                    r⋅sin(α)⋅cos(β)                        ⎞ N_j + ⎛
# ──────────────────────────────────────────────────────────⎟       ⎜───────────
# __________________________________________________________⎟       ⎜   ________
# 2    2       2       2    2                             2 ⎟       ⎜  ╱  2    2
#  ⋅sin (α)⋅cos (β) + r ⋅sin (β) + (-aₓ + r⋅cos(α)⋅cos(β))  ⎠       ⎝╲╱  r ⋅sin
#
#                  r⋅sin(β)                           ⎞ N_k
# ────────────────────────────────────────────────────⎟
# ____________________________________________________⎟
#        2       2    2                             2 ⎟
# (α)⋅cos (β) + r ⋅sin (β) + (-aₓ + r⋅cos(α)⋅cos(β))  ⎠

# %% [markdown]
# Compute $\tilde{E}_r(\alpha, \beta) \cdot \hat{n}$ where $\hat{n}$ is normal unit vector to gaussian sphere

# %%
e = q/(p2.dot(p2)*4*pi*eps0)*puv.dot(nuv)
e1=e.factor().trigsimp()
e1
# Out:
#          q⋅(-aₓ⋅cos(α)⋅cos(β) + r)
# ───────────────────────────────────────────
#                                         3/2
#        ⎛  2                           2⎞
# 4⋅π⋅ε₀⋅⎝aₓ  - 2⋅aₓ⋅r⋅cos(α)⋅cos(β) + r ⎠

# %%
e2 = e1.subs(ax,k*r).factor().simplify()
e2
# Out:
#         -q⋅(k⋅cos(α)⋅cos(β) - 1)
# ─────────────────────────────────────────
#                                       3/2
#         2 ⎛ 2                        ⎞
# 4⋅π⋅ε₀⋅r ⋅⎝k  - 2⋅k⋅cos(α)⋅cos(β) + 1⎠

# %% [markdown]
# Now we wish to evaluate $ \iint_{S}  E \cdot dA = \iint_{S} E \cdot \tilde{n} \space d \alpha \space d \beta $

# %%
def fn1(xs,k1):
    res = [e2.subs([(beta,0),(k,k1),(alpha,np.pi*x),(q,1),(r,1),(eps0, 8.854187817e-12)]).evalf() for x in xs]
    return res


axis, plt = plotfn(fn1, -2, 2, [0,0.4,0.6,0.7],
                 legend_var="k", 
                 title="Electric field at surface",
                 xlabel = "\u03b1 ($\pi$ radians)",
                 figsize=(6,5))
axis.set_ylabel("E Field (N/C)")
plt.show()

# %%
def fn1(xs,k1):
    res = [e2.subs([(beta,0),(k,k1),(alpha,np.pi*x),(q,1),(r,1),(eps0, 1)]).evalf() for x in xs]
    return res


axis, plt = plotfn(fn1, -2, 2, [0,0.4,0.6,0.7],
                 legend_var="k", 
                 title="Electric field at surface",
                 xlabel = "\u03b1 ($\pi$ radians)",
                 figsize=(6,5))
axis.set_ylabel("E Field (Unitised)")
plt.show()

# %%
from scipy.integrate import quad, trapz, simps
from functools import partial

x = np.linspace(0,2,100)
y = fn1(x,0.7)
func = lambda x: fn1(x,0.7)
dsolution = trapz(y, x=x)
print (dsolution)
ds = simps(y,x)
print (ds)
fs = quad(func,0,2)
print (fs)
# Out:
# 0.269327825243268
# 0.269206604368651
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-99d437dc71eb> in <module>()
#       9 ds = simps(y,x)
#      10 print (ds)
# ---> 11 fs = quad(func,0,2)
#      12 print (fs)
#
# ~/venvs/jupyter/lib/python3.5/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     321     if (weight is None):
#     322         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 323                        points)
#     324     else:
#     325         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# ~/venvs/jupyter/lib/python3.5/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     386     if points is None:
#     387         if infbounds == 0:
# --> 388             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     389         else:
#     390             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-27-99d437dc71eb> in <lambda>(x)
#       4 x = np.linspace(0,2,100)
#       5 y = fn1(x,0.7)
# ----> 6 func = lambda x: fn1(x,0.7)
#       7 dsolution = trapz(y, x=x)
#       8 print (dsolution)
#
# <ipython-input-20-b56686b1381f> in fn1(xs, k1)
#       1 def fn1(xs,k1):
# ----> 2     res = [e2.subs([(beta,0),(k,k1),(alpha,np.pi*x),(q,1),(r,1),(eps0, 1)]).evalf() for x in xs]
#       3     return res
#       4
#       5
#
# TypeError: 'float' object is not iterable

# %%
def fn2(xs,beta1):
    res = [e2.subs([(beta,np.pi*beta1),(k,0.7),(alpha,np.pi*x),(q,1),(r,1),(eps0, 8.854187817e-12)]).evalf() for x in xs]
    return res


axis, plt = plotfn(fn2, -0.5, 0.5, [0,0.1,0.3, 0.5,1],
                 legend_var="\u03b2", 
                 title="Electric field at surface for k=0.7",
                 xlabel = "\u03b1 ($\pi$ radians)",
                 figsize=(6,5))
axis.set_ylabel("E Field (N/C)")
plt.show()

# %%
m1.jacobian(m2)
# Out:
# ⎡cos(α)⋅cos(β)  -r⋅sin(α)⋅cos(β)  -r⋅sin(β)⋅cos(α)⎤
# ⎢                                                 ⎥
# ⎢sin(α)⋅cos(β)  r⋅cos(α)⋅cos(β)   -r⋅sin(α)⋅sin(β)⎥
# ⎢                                                 ⎥
# ⎣   sin(β)             0              r⋅cos(β)    ⎦

# %%
ex3 = m1.jacobian(m2).det()
ex3.factor().trigsimp()

# %%
expr1 = y**2-r**2+x**2
expr1

# %%
expr2 = y**2-r**2+(x-a)**2
expr2

# %%
expr0 = y-tan(alpha)*(x-a)
expr0

# %%
solns1 = solve([expr0, expr1], x,y)
solns1[1]

# %%
solns2 = solve([expr0, expr2], x,y)
solns2[1]
