# %%
import pandas as pd
import numpy as np
import string

# %%
df= pd.read_excel('stats/itm-apr17-tables.xls', sheetname=8)
row_count, col_count = df.shape
col_names = [string.ascii_uppercase[i] for i in range(col_count)]
df.columns = col_names
df.rename(columns={'A':'Region','B':'Country'},inplace=True)
df
# Out:
#                                          Region  \
# 0                                           NaN
# 1      Net permanent and long-term migration(1)
# 2   By country of last/next permanent residence
# 3                                           NaN
# 4                          Country of last/next
# 5                           permanent residence
# 6                                           NaN
# 7                                       Oceania
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                         Asia
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# ...

# %%
df1 = df.iloc[7:52].replace(np.nan,'').dropna(axis='index',how='all').set_index(['Region','Country'])
df1.rename(columns={'C':'Apr-2015','D':'Apr-2016','E':'Apr-2017','F':'2015','G':'2016','H':'2017'})
# Out:
#                                                        Apr-2015 Apr-2016  \
# Region                     Country
# Oceania                                                     261      197
#                            Australia                         63      -78
#                            Fiji                              49      142
#                            Samoa                             65      104
#                            Tonga                             61       32
#
# Asia                                                       2159     2314
#                            China, People's Republic of      446      485
#                            Hong Kong (SAR)                   35       68
#                            India                            667      621
#                            Indonesia                          9       16
#                            Japan                            263      316
# ...

# %%
from sympy import *

# %%
x,y,z = symbols('x y z')

# %%
integrate(sin(x),x)
# Out:
# -cos(x)

# %%
init_printing()

# %%
1/sin(x)
# Out:
#   1
# ──────
# sin(x)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2*np.pi*t)
plt.plot(t, s)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('About as simple as it gets, folks')
plt.grid(True)
plt.savefig("test.png")
plt.show()

# %%
import string
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
# set dataframe column names to alphabetic letters A, B, C, D, etc
import string
row_count, col_count = df.shape
col_names = [string.ascii_uppercase[i] for i in range(col_count)]
df.columns = col_names
df
# Out:
#                                               A  \
# 0                                           NaN
# 1      Net permanent and long-term migration(1)
# 2   By country of last/next permanent residence
# 3                                           NaN
# 4                          Country of last/next
# 5                           permanent residence
# 6                                           NaN
# 7                                       Oceania
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                         Asia
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# ...

# %%
df.drop(range(4),axis=0)
# Out:
#                                           A  \
# 4                      Country of last/next
# 5                       permanent residence
# 6                                       NaN
# 7                                   Oceania
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                     Asia
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 10 columns):
# A    17 non-null object
# B    38 non-null object
# C    42 non-null object
# D    41 non-null float64
# E    41 non-null float64
# F    42 non-null object
# G    41 non-null float64
# H    41 non-null float64
# I    42 non-null object
# J    41 non-null object
# dtypes: float64(4), object(6)
# memory usage: 5.0+ KB

# %%
df2 = df.set_index(['A','B'])
df2
# Out:
#                                                                                                              C  \
# A                                           B
# NaN                                         NaN                                                            NaN
# Net permanent and long-term migration(1)    NaN                                                            NaN
# By country of last/next permanent residence NaN                                                            NaN
# NaN                                         NaN                                                            NaN
# Country of last/next                        NaN                                                 April month(2)
# permanent residence                         NaN                                                           2015
# NaN                                         NaN                                                            NaN
# ...

# %%
x = pd.DataFrame(np.array([[1,2,-1],[1,4,6]]),index=[1,2],columns=['a','b','c'])
x
# Out:
#    a  b  c
# 1  1  2 -1
# 2  1  4  6

# %%
x[x.c>0]
# Out:
#    a  b  c
# 2  1  4  6

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, 10, 500)
dashes = [1, 5, 3, 5]  # 10 points on, 5 off, 100 on, 5 off

fig, ax = plt.subplots()

line2, = ax.plot(x, -1 * np.sin(x), dashes=[1,2,1, 5, 3, 5],
                 label='Dashes set proactively', lw=2)

ax.legend(loc='lower right')
plt.show()

# %%
"""
=====
Decay
=====

This example showcases a sinusoidal decay animation.
"""


import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation


def data_gen(t=0):
    cnt = 0
    while cnt < 1000:
        cnt += 1
        t += 0.1
        yield t, np.sin(2*np.pi*t) * np.exp(-t/10.)


def init():
    ax.set_ylim(-1.1, 1.1)
    ax.set_xlim(0, 10)
    del xdata[:]
    del ydata[:]
    line.set_data(xdata, ydata)
    return line,

fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.grid()
xdata, ydata = [], []


def run(data):
    # update the data
    t, y = data
    xdata.append(t)
    ydata.append(y)
    xmin, xmax = ax.get_xlim()

    if t >= xmax:
        ax.set_xlim(xmin, 2*xmax)
        ax.figure.canvas.draw()
    line.set_data(xdata, ydata)

    return line,

ani = animation.FuncAnimation(fig, run, data_gen, blit=False, interval=10,
                              repeat=False, init_func=init)
plt.show()

# %%
I = Function('I', real=True)
Q.real(I)
t,L,R,V,C = symbols('t L R V C')
QF = Function('Q')

# %%
R*I(t)
# Out:
# R⋅I(t)

# %%
diffeqn = V-R*I(t)-L*Derivative(I(t),t)
diffeqn
# Out:
#     d
# - L⋅──(I(t)) - R⋅I(t) + V
#     dt

# %%
dsolve(diffeqn, I(t))
# Out:
#             R⋅(C₁ - t)
#             ──────────
#                 L
#        V + ℯ
# I(t) = ───────────────
#               R

# %%
diffeqn2 = V - L*Derivative(QF(t),t,t)-QF(t)/C
diffeqn2
# Out:
#       2
#      d              Q(t)
# - L⋅───(Q(t)) + V - ────
#       2              C
#     dt

# %%
ds = dsolve(diffeqn2,QF(t))
ds
# Out:
#                         _____             _____
#                        ╱ -1              ╱ -1
#                  -t⋅  ╱  ───        t⋅  ╱  ───
#                     ╲╱   C⋅L          ╲╱   C⋅L
# Q(t) = C⋅V + C₁⋅ℯ             + C₂⋅ℯ

# %%
diff(ds.args[1],t)
# Out:
#                        _____                       _____
#                       ╱ -1                        ╱ -1
#          _____  -t⋅  ╱  ───           _____  t⋅  ╱  ───
#         ╱ -1       ╲╱   C⋅L          ╱ -1      ╲╱   C⋅L
# - C₁⋅  ╱  ─── ⋅ℯ             + C₂⋅  ╱  ─── ⋅ℯ
#      ╲╱   C⋅L                     ╲╱   C⋅L

# %%
"""
Simple demo with multiple subplots.
"""
import numpy as np
import matplotlib.pyplot as plt


x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(2,1,1)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax = fig.add_subplot(2,1,2)

plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()
