# %%
import pandas as pd
import numpy as np
import string
import matplotlib.pyplot as plt
from pylab import savefig

# %%
# %matplotlib inline

# %%
df= pd.read_excel('stats/exports-yemar17-tables.xlsx')
df.head(8)
# Out:
#   Goods and Services Trade by Country: Year ended March 2017  \
# 0                                                NaN
# 1                                     List of tables
# 2                                                  1
# 3                                                  2
# 4                                                  3
# 5                                                  4
# 6                                                  5
# 7                                                  6
#
#                                           Unnamed: 1  Unnamed: 2
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2     New Zealand's total trade, by top 25 countries         NaN
# 3  Exports by destination, top 25 countries and e...         NaN
# 4                Total exports, by top 30 categories         NaN
# 5  Top 25 exports, by commodity/service and desti...         NaN
# ...

# %%
df= pd.read_excel('stats/exports-yemar17-tables.xlsx', sheetname=3)
# set dataframe column names to alphabetic letters A, B, C, D, etc
import string
row_count, col_count = df.shape
col_names = [[y+x.strip() for x,y in itertools.product(' 123456789', string.ascii_uppercase)][i] for i in range(col_count)]
df.columns = col_names
df.head(17)
# Out:
#                                      A              B           C  \
# 0                        Total exports            NaN         NaN
# 1                 By top 30 categories            NaN         NaN
# 2                     Year ended March            NaN         NaN
# 3                  Commodity / service  Exports (fob)         NaN
# 4                                  NaN           2016         NaN
# 5                                  NaN   NZ$(million)  % of total
# 6                                  NaN            NaN         NaN
# 7      Milk powder, butter, and cheese        11279.3     16.0802
# 8   Business and other personal travel        10198.3      14.539
# 9                Meat and edible offal         6579.5     9.37996
# 10       Logs, wood, and wood articles        3614.79     5.15337
# 11                    Education travel        3416.72     4.87099
# 12                               Fruit        2361.87     3.36715
# ...

# %%
df1 = df.loc[4:36,'A':'E'].dropna(how='all').replace(np.nan,'')
df1
# Out:
#                                                     A             B  \
# 4                                                              2016
# 5                                                      NZ$(million)
# 7                     Milk powder, butter, and cheese       11279.3
# 8                  Business and other personal travel       10198.3
# 9                               Meat and edible offal        6579.5
# 10                      Logs, wood, and wood articles       3614.79
# 11                                   Education travel       3416.72
# 12                                              Fruit       2361.87
# 13                                      Air transport       2112.96
# 14                                               Wine       1558.26
# 15                 Mechanical machinery and equipment       1700.11
# 16                    Fish, crustaceans, and molluscs       1526.74
# 17         Preparations of cereals, flour, and starch       965.337
# ...

# %%
fig, ax = plt.subplots()

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print ("Current size:" + repr(fig_size))
 
# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

# Example data
xseries = df1.loc[7:]['A']
y_pos = np.arange(len(xseries))
yseries = df1.loc[7:]['D']

ax.barh(y_pos, yseries, align='center',
        color='lightblue', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(xseries)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Export Value in NZ$(million)')
ax.set_title('Exports as at March 2017')

plt.show()
# Out:
# Current size:[12.0, 9.0]
